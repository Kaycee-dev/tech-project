# %%
import pandas as pd
df  = pd.read_excel("D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx",skiprows=1)
df = df.set_index("REGION")
# df.iloc[0] = df.iloc[0].fillna(method='ffill', axis=1)
df.loc[:]
df.iloc[0]
# Out:
# 2020-03-11 12:00:00            2G AVAIL(%)
# Unnamed: 2                     3G AVAIL(%)
# Unnamed: 3                     4G AVAIL(%)
# 2020-03-11 13:00:00            2G AVAIL(%)
# Unnamed: 5                     3G AVAIL(%)
# Unnamed: 6                     4G AVAIL(%)
# 2020-03-11 14:00:00            2G AVAIL(%)
# Unnamed: 8                     3G AVAIL(%)
# Unnamed: 9                     4G AVAIL(%)
# 2020-03-11 15:00:00            2G AVAIL(%)
# Unnamed: 11                    3G AVAIL(%)
# Unnamed: 12                    4G AVAIL(%)
# Unnamed: 13                            NaN
# Time                   2020-03-11 12:00:00
# Country                            Nigeria
# 2G AVAIL(%)                          98.79
# 3G AVAIL(%)                          98.29
# 4G AVAIL(%)                          99.38
# Name: nan, dtype: object

# %%
import pandas as pd
df  = pd.read_excel("D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx",skiprows=1)
df = df.set_index("REGION")
# df.iloc[0] = df.iloc[0].fillna(method='ffill', axis=1)
df.loc[:]
# df.iloc[0]
# Out:
#        2020-03-11 12:00:00   Unnamed: 2   Unnamed: 3 2020-03-11 13:00:00  \
# REGION
# NaN            2G AVAIL(%)  3G AVAIL(%)  4G AVAIL(%)         2G AVAIL(%)
# ABJ                98.5022      98.7591      99.5229             98.9913
# ASB                99.0545       98.841      99.4089             98.8195
# ENG                99.0916      99.0027      99.6194             98.9045
# IBD                 99.171      98.8402      99.5237             99.1699
# KNO                 98.065      98.4485      99.3134             97.3755
# LGS                95.8561      96.5828      98.7698             95.7763
# PHC                99.1917      99.2497      99.9129             99.3282
#
#          Unnamed: 5   Unnamed: 6 2020-03-11 14:00:00   Unnamed: 8  \
# REGION
# NaN     3G AVAIL(%)  4G AVAIL(%)         2G AVAIL(%)  3G AVAIL(%)
# ABJ         99.1147      99.5382             98.9648      98.8156
# ASB         98.7032      99.6793             98.5846      98.5838
# ...

# %%
import pandas as pd
nam = "Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx"
df  = pd.read_excel(f"D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\{nam}", index_col=None, na_values=['NA'], skiprows=1)
df = df.set_index("REGION")
# df.iloc[0] = df.iloc[0].fillna(method='ffill', axis=1)
# df.loc[1]
# df.iloc[:]
# df.columns = df.iloc[0].fillna(method='ffill')
df
# Out:
#        2020-03-11 12:00:00   Unnamed: 2   Unnamed: 3 2020-03-11 13:00:00  \
# REGION
# NaN            2G AVAIL(%)  3G AVAIL(%)  4G AVAIL(%)         2G AVAIL(%)
# ABJ                98.5022      98.7591      99.5229             98.9913
# ASB                99.0545       98.841      99.4089             98.8195
# ENG                99.0916      99.0027      99.6194             98.9045
# IBD                 99.171      98.8402      99.5237             99.1699
# KNO                 98.065      98.4485      99.3134             97.3755
# LGS                95.8561      96.5828      98.7698             95.7763
# PHC                99.1917      99.2497      99.9129             99.3282
#
#          Unnamed: 5   Unnamed: 6 2020-03-11 14:00:00   Unnamed: 8  \
# REGION
# NaN     3G AVAIL(%)  4G AVAIL(%)         2G AVAIL(%)  3G AVAIL(%)
# ABJ         99.1147      99.5382             98.9648      98.8156
# ASB         98.7032      99.6793             98.5846      98.5838
# ...

# %%
import pandas as pd
nam = "Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx"
df  = pd.read_excel(f"D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\{nam}", index_col=None, na_values=['NA'], skiprows=1)
df = df.set_index("REGION")
# df

ml = df.columns.tolist()
# print(ml)

for i in ml:
    if "Unnamed" in i and "Time" not in ml[ml.index(i) + 1]:
        ml[ml.index(i)] = ml[ml.index(i) - 1]
df.columns = ml
df = df.iloc[:,:12]
df
# for each in df.index[1:]:
#     print(each)
# Out:
#        2020-03-11 12:00:00 2020-03-11 12:00:00 2020-03-11 12:00:00  \
# REGION
# NaN            2G AVAIL(%)         3G AVAIL(%)         4G AVAIL(%)
# ABJ                98.5022             98.7591             99.5229
# ASB                99.0545              98.841             99.4089
# ENG                99.0916             99.0027             99.6194
# IBD                 99.171             98.8402             99.5237
# KNO                 98.065             98.4485             99.3134
# LGS                95.8561             96.5828             98.7698
# PHC                99.1917             99.2497             99.9129
#
#        2020-03-11 13:00:00 2020-03-11 13:00:00 2020-03-11 13:00:00  \
# REGION
# NaN            2G AVAIL(%)         3G AVAIL(%)         4G AVAIL(%)
# ABJ                98.9913             99.1147             99.5382
# ASB                98.8195             98.7032             99.6793
# ENG                98.9045             98.8783             99.5615
# ...

# %%
import pandas as pd
nam = "Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx"
df  = pd.read_excel(f"D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\{nam}", index_col=None, na_values=['NA'], skiprows=1)
df = df.set_index("REGION")
# df

ml = df.columns.tolist()
# print(ml)

for i in ml:
    if "Unnamed" in i and "Time" not in ml[ml.index(i) + 1]:
        ml[ml.index(i)] = ml[ml.index(i) - 1]
df.columns = ml
df = df.iloc[1:,:12]
df
# Out:
#        2020-03-11 12:00:00 2020-03-11 12:00:00 2020-03-11 12:00:00  \
# REGION
# ABJ                98.5022             98.7591             99.5229
# ASB                99.0545              98.841             99.4089
# ENG                99.0916             99.0027             99.6194
# IBD                 99.171             98.8402             99.5237
# KNO                 98.065             98.4485             99.3134
# LGS                95.8561             96.5828             98.7698
# PHC                99.1917             99.2497             99.9129
#
#        2020-03-11 13:00:00 2020-03-11 13:00:00 2020-03-11 13:00:00  \
# REGION
# ABJ                98.9913             99.1147             99.5382
# ASB                98.8195             98.7032             99.6793
# ENG                98.9045             98.8783             99.5615
# IBD                99.1699             99.1208             99.7586
# KNO                97.3755             98.0567             99.0537
# ...

# %%
import pandas as pd
nam = "Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx"
df  = pd.read_excel(f"D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\{nam}", sheet_name=0, index_col=None, na_values=['NA'], skiprows=1)
df = df.set_index("REGION")
# df
df.fillna('')

ml = df.columns.tolist()

for i in ml:
    if "Unnamed" in i and "Time" not in ml[ml.index(i) + 1]:
        ml[ml.index(i)] = ml[ml.index(i) - 1]
df.columns = ml
df = df.iloc[1:,:12]
# df.index.tolist()[3]
# df.columns.tolist()[2]

times,regions,techs = df.columns.tolist(),df.index.tolist(),["2G","3G","4G"]
techs = techs * (len(times)//len(techs))
count = 0

for tech,time in zip(techs,times):
    for region in range(len(regions)):
#         print(f'Time is {time}, Region is {regions[region]}, Availability is {"{0:.2f}".format(df.iloc[region,count%12])}, and Technology is {tech}')
        print(f'Time is {str(time)[:10]}, Region is {regions[region]}, Availability is {round(float(df.iloc[region,count%12]),2)}, and Technology is {tech}')
    count += 1
print(count)
# Out:
# Time is 2020-03-11, Region is ABJ, Availability is 98.5, and Technology is 2G
# Time is 2020-03-11, Region is ASB, Availability is 99.05, and Technology is 2G
# Time is 2020-03-11, Region is ENG, Availability is 99.09, and Technology is 2G
# Time is 2020-03-11, Region is IBD, Availability is 99.17, and Technology is 2G
# Time is 2020-03-11, Region is KNO, Availability is 98.06, and Technology is 2G
# Time is 2020-03-11, Region is LGS, Availability is 95.86, and Technology is 2G
# Time is 2020-03-11, Region is PHC, Availability is 99.19, and Technology is 2G
# Time is 2020-03-11, Region is ABJ, Availability is 98.76, and Technology is 3G
# Time is 2020-03-11, Region is ASB, Availability is 98.84, and Technology is 3G
# Time is 2020-03-11, Region is ENG, Availability is 99.0, and Technology is 3G
# Time is 2020-03-11, Region is IBD, Availability is 98.84, and Technology is 3G
# Time is 2020-03-11, Region is KNO, Availability is 98.45, and Technology is 3G
# ...

# %%
import os
os.getcwd()
# Out:
# 'C:\\Users\\uwx815001'

# %%
import pandas as pd
nam = "Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx"
df  = pd.read_excel(f"D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\{nam}", index_col=None, na_values=['NA'], skiprows=1)

df = df.iloc[:4,14:19]
df = df.set_index("Time")
df
# Out:
#                      Country  2G AVAIL(%)  3G AVAIL(%)  4G AVAIL(%)
# Time
# 2020-03-11 12:00:00  Nigeria        98.79        98.29        99.38
# 2020-03-11 13:00:00  Nigeria        98.75        98.30        99.45
# 2020-03-11 14:00:00  Nigeria        98.76        98.12        99.43
# 2020-03-11 15:00:00  Nigeria        98.74        98.03        99.38

# %%
import pandas as pd
nam = "Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx"
df  = pd.read_excel(f"D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\{nam}", index_col=None, na_values=['NA'], skiprows=1)

df = df.iloc[:4,14:19]
df = df.set_index("Time")
df

times,country,techs = df.index.tolist(),"Nigeria",["2G","3G","4G"]
count = 1

for tech in techs:
    for time in range(len(times)):
        print(f'Time is {str(times[time])[:10]}, Country is {country}, Availability is {"{0:.2f}".format(df.iloc[time,count%4])}, and Technology is {tech}')
    count += 1
print(count)
# Out:
# Time is 2020-03-11, Country is Nigeria, Availability is 98.79, and Technology is 2G
# Time is 2020-03-11, Country is Nigeria, Availability is 98.75, and Technology is 2G
# Time is 2020-03-11, Country is Nigeria, Availability is 98.76, and Technology is 2G
# Time is 2020-03-11, Country is Nigeria, Availability is 98.74, and Technology is 2G
# Time is 2020-03-11, Country is Nigeria, Availability is 98.29, and Technology is 3G
# Time is 2020-03-11, Country is Nigeria, Availability is 98.30, and Technology is 3G
# Time is 2020-03-11, Country is Nigeria, Availability is 98.12, and Technology is 3G
# Time is 2020-03-11, Country is Nigeria, Availability is 98.03, and Technology is 3G
# Time is 2020-03-11, Country is Nigeria, Availability is 99.38, and Technology is 4G
# Time is 2020-03-11, Country is Nigeria, Availability is 99.45, and Technology is 4G
# Time is 2020-03-11, Country is Nigeria, Availability is 99.43, and Technology is 4G
# ...

# %%
import pandas as pd
nam = "Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx"
df  = pd.read_excel(f"D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\{nam}", sheet_name=0, index_col=None, na_values=['NA'], skiprows=1)
df = df.set_index("REGION")
df.fillna('')
df
# Out:
#        2020-03-11 12:00:00   Unnamed: 2   Unnamed: 3 2020-03-11 13:00:00  \
# REGION
# NaN            2G AVAIL(%)  3G AVAIL(%)  4G AVAIL(%)         2G AVAIL(%)
# ABJ                98.5022      98.7591      99.5229             98.9913
# ASB                99.0545       98.841      99.4089             98.8195
# ENG                99.0916      99.0027      99.6194             98.9045
# IBD                 99.171      98.8402      99.5237             99.1699
# KNO                 98.065      98.4485      99.3134             97.3755
# LGS                95.8561      96.5828      98.7698             95.7763
# PHC                99.1917      99.2497      99.9129             99.3282
#
#          Unnamed: 5   Unnamed: 6 2020-03-11 14:00:00   Unnamed: 8  \
# REGION
# NaN     3G AVAIL(%)  4G AVAIL(%)         2G AVAIL(%)  3G AVAIL(%)
# ABJ         99.1147      99.5382             98.9648      98.8156
# ASB         98.7032      99.6793             98.5846      98.5838
# ...

# %%
import pandas as pd
nam = "Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx"
df  = pd.read_excel(f"D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\{nam}", sheet_name=0, index_col=None, na_values=['NA'], skiprows=1)
df = df.set_index("REGION")
# df
df.fillna('')

ml = df.columns.tolist()

for i in ml:
    if "Unnamed" in i and "Time" not in ml[ml.index(i) + 1]:
        ml[ml.index(i)] = ml[ml.index(i) - 1]
df.columns = ml
df = df.iloc[1:,:12]

times,regions,techs = df.columns.tolist(),df.index.tolist(),["2G","3G","4G"]
time,control = times[len(times)//2],[0,1,2]

count = 0


for region in range(len(regions)):
    for tech in techs:
        print(f'Time is {str(time)[:10]}, Region is {regions[region]}, Availability is {round(float(sum(df.iloc[region,list(range(12))[count%3::3]].tolist())/4),2)}, and Technology is {tech}')
        count += 1

count = 0

for region in range(len(regions)):
# for tech in techs:
    avails = [round(float(sum(df.iloc[region,list(range(12))[count%3::3]].tolist())/4),2),round(float(sum(df.iloc[region,list(range(12))[(count+1)%3::3]].tolist())/4),2),round(float(sum(df.iloc[region,list(range(12))[(count+2)%3::3]].tolist())/4),2)]
    print(f'Time is {str(time)[:10]}, Region is {regions[region]}, Availability is {avails}, and Technology is {techs}')
#     count += 1
print(count)
# Out:
# Time is 2020-03-11, Region is ABJ, Availability is 98.86, and Technology is 2G
# Time is 2020-03-11, Region is ABJ, Availability is 98.91, and Technology is 3G
# Time is 2020-03-11, Region is ABJ, Availability is 99.53, and Technology is 4G
# Time is 2020-03-11, Region is ASB, Availability is 98.71, and Technology is 2G
# Time is 2020-03-11, Region is ASB, Availability is 98.54, and Technology is 3G
# Time is 2020-03-11, Region is ASB, Availability is 99.46, and Technology is 4G
# Time is 2020-03-11, Region is ENG, Availability is 99.02, and Technology is 2G
# Time is 2020-03-11, Region is ENG, Availability is 98.88, and Technology is 3G
# Time is 2020-03-11, Region is ENG, Availability is 99.64, and Technology is 4G
# Time is 2020-03-11, Region is IBD, Availability is 99.21, and Technology is 2G
# Time is 2020-03-11, Region is IBD, Availability is 99.1, and Technology is 3G
# Time is 2020-03-11, Region is IBD, Availability is 99.72, and Technology is 4G
# ...

# %%
import pandas as pd
nam = "Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx"
df  = pd.read_excel(f"D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\{nam}", index_col=None, na_values=['NA'], skiprows=1)

df = df.iloc[:4,14:19]
df = df.set_index("Time")
df

times,country,techs = df.index.tolist(),"Nigeria",["2G","3G","4G"]
count = 1
avails = []

for tech in techs:
#     for time in range(len(times)):
    print(df.iloc[:,count%4].tolist())
#     print(f'Time is {str(times[time])[:10]}, Country is {country}, Availability is {"{0:.2f}".format(round(float(sum(df.iloc[:,count%4].tolist())/4)),2)}, and Technology is {tech}')
    print(f'Time is {str(times[len(times)//2])[:10]}, Country is {country}, Availability is {round(float(sum(df.iloc[:,count%4].tolist())/4),2)}, and Technology is {tech}')
    avails.append(round(float(sum(df.iloc[:,count%4].tolist())/4),2))
    count += 1
print(count)
print(avails)
# Out:
# [98.79, 98.75, 98.76, 98.74]
# Time is 2020-03-11, Country is Nigeria, Availability is 98.76, and Technology is 2G
# [98.29, 98.3, 98.12, 98.03]
# Time is 2020-03-11, Country is Nigeria, Availability is 98.19, and Technology is 3G
# [99.38, 99.45, 99.43, 99.38]
# Time is 2020-03-11, Country is Nigeria, Availability is 99.41, and Technology is 4G
# 4
# [98.76, 98.19, 99.41]

# %%
import pandas as pd
nam = "Hourly and National Regional Availability_new_2020031117_40f7e54eb61b49338a024de454c3787e.xlsx"
df  = pd.read_excel(f"D:\\2020\\Python\\MTN\MAPS_Availbilty\\Input\\{nam}", index_col=None, na_values=['NA'], skiprows=1)

df = df.iloc[:4,14:19]
df = df.set_index("Time")
print(df)
print(df.iloc[:,1].tolist())
# Out:
#                      Country  2G AVAIL(%)  3G AVAIL(%)  4G AVAIL(%)
# Time
# 2020-03-11 12:00:00  Nigeria        98.79        98.29        99.38
# 2020-03-11 13:00:00  Nigeria        98.75        98.30        99.45
# 2020-03-11 14:00:00  Nigeria        98.76        98.12        99.43
# 2020-03-11 15:00:00  Nigeria        98.74        98.03        99.38
# [98.79, 98.75, 98.76, 98.74]
